# %% [markdown]
# # 변수와 통계량

# %%
import numpy as np

# %%
from scipy.stats import kurtosis, skew

# %%
data = np.random.normal(0, 1, 10000000)

# %%
np.mean(data), np.std(data), skew(data), kurtosis(data)
# Out:
# (np.float64(-0.0003528282591848332),
#  np.float64(1.000101337461814),
#  np.float64(0.0005433349910994572),
#  np.float64(-0.0029883998140034507))

# %%
data = np.random.geometric(0.5, 1000)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(data, bins=50)
plt.show()

# %%
np.mean(data), np.median(data)
# Out:
# (np.float64(1.92), np.float64(1.0))

# %%
skew(data)
# Out:
# np.float64(2.0768780776434164)

# %%
kurtosis(data)
# Out:
# np.float64(5.3431490299190205)

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.iloc[:,:-1].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.scatterplot(x="petal_length", y="petal_width",
               data=iris)
plt.show()

# %%
iris.describe(include="all")
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# # 데이터 EDA 가속화

# %%
# !pip install dataprep # 파이썬 3.9 또는 3.10에서만 동작
# conda install -c conda-forge dataprep

# %%
# from dataprep.eda import plot, plot_correlation, plot_missing

# %%
# import seaborn as sns
# iris = sns.load_dataset("iris")

# %%
# plot(iris)

# %%
# plot(iris, "petal_length", config={"hist.bins": 20})

# %%
# plot(iris, "petal_length", "petal_width")

# %%
# plot_correlation(iris)

# %%
# plot_correlation(iris, "petal_length", "petal_width", k=10)

# %%
# plot_missing(iris)
