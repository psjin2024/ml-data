# %% [markdown]
# ### 상관분석

# %%
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
iris.corr(method="pearson", numeric_only=True) # spearman 도 있음
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# -1 ~ 1 사이의 값 출력
# 0~0.3 약한 양의 상관관계
# 0.3~0.6(0.7) 강한 양의 상관관계
# 0.6(0.7) ~ 1 매우 강한 양의 상관관계

# %%
sns.pairplot(iris)

# %%
from scipy.stats import pearsonr
pearsonr(iris.petal_length, iris.petal_width)
# Out:
# PearsonRResult(statistic=np.float64(0.962865431402796), pvalue=np.float64(4.6750039073286175e-86))

# %%
sns.scatterplot(data=iris, x="petal_length", y="petal_width")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# ## 3.2 스미어만 상관계수  p.73

# %%
iris.corr(method="spearman", numeric_only=True) # 스피어만 상관계수, 정규분포를 벗어난 경우 사용
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000

# %%
from scipy.stats import spearmanr
spearmanr(iris.petal_length, iris.petal_width)
# Out:
# SignificanceResult(statistic=np.float64(0.9376668235763412), pvalue=np.float64(8.156596854126633e-70))

# %% [markdown]
# ## 3.3 상관계수  시각화 p.73

# %%
import pandas as pd
redwine = pd.read_csv("winequality-red.csv", delimiter=';')
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
# sns.heatmap(redwine.corr(), vmin=-1, vmax=1, cmap="YlGnBu")
sns.heatmap(redwine.corr(), vmin=-1, vmax=1, annot=True, cmap="cubehelix_r")
plt.show()
