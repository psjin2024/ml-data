# %%
X = [32, 64, 96, 118, 126, 144, 152, 158]
Y = [17, 24, 62, 49, 52, 105, 130, 125]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.c_[X, Y], columns=["x", "y"])

# %%
# !pip install statsmodels
import statsmodels.api as sm
model = sm.OLS.from_formula("y ~ x", data=df)
result = model.fit()
result.params
# Out:
# ...
# Intercept   -27.358463
# x             0.879627
# dtype: float64

# %%
model2 = sm.OLS.from_formula("y ~ I(x**3) + I(x**2) + x -1 ", data=df)
# 포뮬라 에러나면 patsy 패키지 업데이트 conda update patsy

# %%
result2 = model2.fit()
result2.params
# Out:
# I(x ** 3)    0.000082
# I(x ** 2)   -0.013981
# x            1.005637
# dtype: float64

# %%
a,b,c = result2.params

# %%
print(a, b, c)
# Out:
# 8.187110791499301e-05 -0.013981494837003991 1.005636854786575

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y)
plt.plot(X, np.poly1d([a,b,c,0])(X))
plt.show()

# %%
x_df = pd.DataFrame(data=X, columns=['x'])

# %%
y_ = result2.predict(x_df)

# %%
y_
# Out:
# 0     20.546081
# 1     28.554576
# 2     40.121998
# 3     58.503665
# 4     68.513031
# 5     99.357248
# 6    117.343957
# 7    132.781779
# dtype: float64

# %%
plt.scatter(X, Y)
plt.plot(X, y_, '-')
plt.show()

# %%
model4 = sm.OLS.from_formula("y ~ x + I(x**2) + I(x**3) + I(x**4) -1 ", data=df)
# 포뮬라 에러나면 patsy 패키지 업데이트 conda update patsy

# %%
result4 = model4.fit()
y_ = result4.predict(x_df)
plt.scatter(X, Y)
plt.plot(X, y_, '-')
plt.show()
