# %%
import random

# %%
random.seed(10)

# %%
inds = random.sample(range(150), int(150*0.7))

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
train = iris.loc[inds, :]

# %%
train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 8             4.4          2.9           1.4          0.2     setosa
# 109           7.2          3.6           6.1          2.5  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 3             4.6          3.1           1.5          0.2     setosa

# %%
train.sort_index(inplace=True)

# %%
train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
test = iris.loc[~iris.index.isin(train.index)]

# %%
test.sort_index(inplace=True)

# %%
test.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 13           4.3          3.0           1.1          0.1  setosa
# 16           5.4          3.9           1.3          0.4  setosa

# %%
train = iris.sample(frac=0.7)

# %%
train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 118           7.7          2.6           6.9          2.3   virginica
# 83            6.0          2.7           5.1          1.6  versicolor
# 69            5.6          2.5           3.9          1.1  versicolor
# 105           7.6          3.0           6.6          2.1   virginica
# 25            5.0          3.0           1.6          0.2      setosa

# %%
test = iris.loc[~iris.index.isin(train.index)]

# %%
train.shape, test.shape
# Out:
# ((105, 5), (45, 5))

# %%
X = iris.iloc[:,:-1]
y = iris.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y,
                                test_size=0.3)

# %%
train_X.shape, test_X.shape
# Out:
# ((105, 4), (45, 4))

# %%
test_y.value_counts()
# Out:
# species
# versicolor    18
# virginica     15
# setosa        12
# Name: count, dtype: int64

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y,
                            test_size=0.3, stratify=y)

# %%
train_y.value_counts()
# Out:
# species
# versicolor    35
# setosa        35
# virginica     35
# Name: count, dtype: int64

# %%
test_y.value_counts()
# Out:
# species
# virginica     15
# versicolor    15
# setosa        15
# Name: count, dtype: int64

# %%
# 아래처럼 각각의 변수를 따로 샘플링 하면 안됨
train_X, test_X = train_test_split(X, test_size=0.3)
train_y, test_y = train_test_split(y, test_size=0.3)
print(train_X.index)
print(train_y.index) # 선택된 행이 다름
# Out:
# Index([119, 132,  76,  92,  75,  14,  66, 106, 133, 112,
#        ...
#         72,  10,  87,  83,  77,  81,  97,  25,  12,  78],
#       dtype='int64', length=105)
# Index([ 59, 116,  49,  78,  13, 121,  31,  83, 111,  96,
#        ...
#         67, 128,  28, 122,  12,  77, 144,  91,   4,  79],
#       dtype='int64', length=105)
