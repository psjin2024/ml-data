# %%
#  적합도 검정
from scipy.stats import chisquare
data = [19, 41,40]
exp = [20,30,50]
chisquare(data, f_exp=exp)
# Out:
# Power_divergenceResult(statistic=np.float64(6.083333333333333), pvalue=np.float64(0.047755231078826975))
