# %%
import numpy as np
A = np.array([[1, 2, 3], [3, 4, 6]])
print(A)
# Out:
# [[1 2 3]
#  [3 4 6]]

# %%
# 배열의 모든 요소 합하기
total_sum = np.sum(A)
print(f"전체 합: {total_sum}")

# 행별 합
row_sum = np.sum(A, axis=1)
print(f"행별 합: {row_sum}")

# 열별 합
col_sum = np.sum(A, axis=0)
print(f"열별 합: {col_sum}")
# Out:
# 전체 합: 19
# 행별 합: [ 6 13]
# 열별 합: [4 6 9]
